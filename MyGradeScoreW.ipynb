# %%
gradesAndCreditsDict= {
    #First Year:
    "District math 1"   : [80, 4.0],
    "Algebra 1"         : [80, 5.0],
    "Computer Systems"  : [80, 4.0],
    "Computer Science"  : [80, 5.0],
    
    "District math 2"   : [80, 3.0],
    "Calculus 1"        : [80, 6.5] ,
    "Data Strctures"    : [80, 4.0],
    "Advanced C"        : [80, 3.0],
    "OOP C++"           : [80, 5.0],
    
   #Second Year: 
    "Probability"       : [80, 3.5],
    "Algebra 2"         : [80, 4.0],
    "Calculus 2"        : [80, 4.0],
    "Computer Networks" : [80, 3.5],
    "Algo 1"            : [60, 4.0], #you're a freak if there is by any chance you got above the 80 mark in this course, good job you lucky bastard xD
    
    "Operating Systems"    : [80, 3.5],
    "Software Engineering" : [80, 4.0],
    "Data Science"         : [80, 3.5],
    "Data Bases"           : [80, 4.0],
    "Machine Learning"     : [80, 4.0],
    "Algo 2"               : [80, 4.0],
    
   #Thired Year: 
    "Automata theory" : [80, 4.0],
    "Complexity Algo" : [80, 4.0],
    
   #Choise: 
    "Yezamut"         : [100, 2.0], #Advanced Tech English 
    "RavThumi"        : [100, 4.0], #Medicine and Tech
    "rav thumi 2"     : [0, 0],
    
    "Project 1" : [0, 0],
    "Project 2" : [0, 0],
    
    "Course Bhira 1" : [100, 3.0], #C#
    "Course Bhira 2" : [100, 3.0], #DevOps
    "Course Bhira 3" : [100, 3.0], #Design Patterns
    "Course Bhira 4" : [100, 3.5], #Advance SE Problem solving 1
    "Course Bhira 5" : [100, 3.5], #Advance SE Problem solving 2
    "Course Bhira 6" : [100, 3.5], #Project 1
    "Course Bhira 7" : [100, 3.5], #Project 2
    "Course Bhira 8" : [100, 3.0], # IDK yet xd
}

# %%
gradeIndex = 0
creditIndex = 1 
totalCredits = 0.0
grades = 0.0

print("\nFirst year:\n")

for className in gradesAndCreditsDict:
    if gradesAndCreditsDict[className][gradeIndex] != 0:
            print(f"{className:<21}{str(gradesAndCreditsDict[className][gradeIndex]):>8}{str(gradesAndCreditsDict[className][creditIndex]):>5}")
            
            totalCredits += gradesAndCreditsDict[className][creditIndex]
            
            grades += gradesAndCreditsDict[className][gradeIndex]*gradesAndCreditsDict[className][creditIndex]
    if className == "OOP C++":
        print("\nSecond year:\n")
    if className == "Algo 2":
        print("\nThired year:\n")
    if className == "Complexity Algo":
        print("\nSidequests:\n")

print("\nTotal credis: " + str(totalCredits) + " Credits")

if totalCredits != 0:        
    print("\nAverege Score: {:.2f}".format(grades/totalCredits))

else:
    print("You didnt enter anything...")
# Out:
# First year:
#
# District math 1            80  4.0
# Algebra 1                  80  5.0
# Computer Systems           80  4.0
# Computer Science           80  5.0
# District math 2            80  3.0
# Calculus 1                 80  6.5
# Data Strctures             80  4.0
# Advanced C                 80  3.0
# OOP C++                    80  5.0
#
# Second year:
#
# Probability                80  3.5
# Algebra 2                  80  4.0
# Calculus 2                 80  4.0
# Computer Networks          80  3.5
# Algo 1                     60  4.0
# Operating Systems          80  3.5
# Software Engineering       80  4.0
# Data Science               80  3.5
# Data Bases                 80  4.0
# Machine Learning           80  4.0
# Algo 2                     80  4.0
#
# Thired year:
#
# Automata theory            80  4.0
# Complexity Algo            80  4.0
#
# Sidequests:
#
# Yezamut                   100  2.0
# RavThumi                  100  4.0
# Course Bhira 1            100  3.0
# ...
